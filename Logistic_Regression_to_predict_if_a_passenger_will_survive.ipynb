# %% [markdown]
# <a href="https://colab.research.google.com/github/sijixx/Logistic-Regression-to-predict-survival-rate/blob/main/Logistic_Regression_to_predict_if_a_passenger_will_survive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-fb1f0d81-4664-4050-9afe-632eb8df64b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb1f0d81-4664-4050-9afe-632eb8df64b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.xlsx to train.xlsx

# %%
df= pd.read_excel('train.xlsx')
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
gender= pd.get_dummies(df["Sex"],drop_first="first")

# %%
df["Gender"]= gender
df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Gender
# 0              1         0       3  ...   NaN        S       1
# 1              2         1       1  ...   C85        C       0
# 2              3         1       3  ...   NaN        S       0
# 3              4         1       1  ...  C123        S       0
# 4              5         0       3  ...   NaN        S       1
# ..           ...       ...     ...  ...   ...      ...     ...
# 886          887         0       2  ...   NaN        S       1
# 887          888         1       1  ...   B42        S       0
# 888          889         0       3  ...   NaN        S       0
# 889          890         1       1  ...  C148        C       1
# 890          891         0       3  ...   NaN        Q       1
#
# [891 rows x 13 columns]

# %%
df.drop(["Name","Sex","Ticket","Embarked",'Cabin'],axis=1,inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Gender
# 0            1         0       3  22.0      1      0   7.2500       1
# 1            2         1       1  38.0      1      0  71.2833       0
# 2            3         1       3  26.0      0      0   7.9250       0
# 3            4         1       1  35.0      1      0  53.1000       0
# 4            5         0       3  35.0      0      0   8.0500       1

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Gender         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

x= df[['PassengerId', 'Pclass', "Age", 'SibSp', "Parch", 'Fare', "Gender"]]
y= df["Survived"]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=30,random_state=40)

# %%
train_lg= LogisticRegression()
train_lg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
train_predict= train_lg.predict(x_test)

# %%
print("Accuracy={:2f}".format(train_lg.score(x_test,y_test)))
# Out:
# Accuracy=0.633333

# %%
train_cof= pd.crosstab(y_test,train_predict,rownames=["Actual"],colnames=["Predicted"])
train_cof
# Out:
# Predicted   0  1
# Actual
# 0          12  7
# 1           4  7

# %%
sns.heatmap(train_cof,annot=True)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.63      0.69        19
#            1       0.50      0.64      0.56        11
#
#     accuracy                           0.63        30
#    macro avg       0.62      0.63      0.62        30
# weighted avg       0.66      0.63      0.64        30
